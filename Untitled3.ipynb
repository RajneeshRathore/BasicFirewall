# %% [markdown]
# <a href="https://colab.research.google.com/github/RajneeshRathore/BasicFirewall/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas Series
#
# #### A series is an one dimension labelled array capable of holding any datatype . The axis labels(index) are collectively called the index.

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
list = [10,20,30]

pd.Series(list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ##Dataframe -> when we combine multiple series

# %%
data = {
        "Name":["Rajneesh","Rohit","Alex","Anuj"],
        "Age":[18,25,30,35],
        "City":["India","NewYork","America","Austriala"],
        "Salary":[900000,100000,2000000,400000]
       }
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#        Name  Age       City   Salary
# 0  Rajneesh   18      India   900000
# 1     Rohit   25    NewYork   100000
# 2      Alex   30    America  2000000
# 3      Anuj   35  Austriala   400000

# %%
list_data = [
             ["Rajneesh",18,"India",900000],
              ["Rohit",   25   , "NewYork",   100000],
             [ "Alex"  , 30    ,"America",  2000000],
             [ "Anuj",   35 ,"Austriala",   400000]
            ]
# pd.DataFrame(list_data)
colums =  [ "Name",  "Age", "City", "Salary"]
df2 = pd.DataFrame(list_data,columns=colums)

# %% [markdown]
# ##Selection And Indexing of Columns

# %%
df2[["Name","Age","City"]] # selection of an column
df2["Gender"]=["Male","Male","Male","Male"] # creating a new column

# %%
df2
# Out:
#        Name  Age       City   Salary Gender
# 0  Rajneesh   18      India   900000   Male
# 1     Rohit   25    NewYork   100000   Male
# 2      Alex   30    America  2000000   Male
# 3      Anuj   35  Austriala   400000   Male

# %%
df2.drop("Gender",axis=1,inplace=True) # it showing the copy of an dataframe so we use the inplace =True to completely delete the column

# %%
df2
# Out:
#        Name  Age       City   Salary
# 0  Rajneesh   18      India   900000
# 1     Rohit   25    NewYork   100000
# 2      Alex   30    America  2000000
# 3      Anuj   35  Austriala   400000

# %% [markdown]
# ##Removing the Row from the DataFrame

# %%
df2.drop(1,axis=0)
# Out:
#        Name  Age       City   Salary
# 0  Rajneesh   18      India   900000
# 2      Alex   30    America  2000000
# 3      Anuj   35  Austriala   400000

# %% [markdown]
# ##Selecting row

# %%
df2.loc[[0,3]]
# Out:
#        Name  Age       City  Salary
# 0  Rajneesh   18      India  900000
# 3      Anuj   35  Austriala  400000

# %%
df2.iloc[0]
# Out:
# Name      Rajneesh
# Age             18
# City         India
# Salary      900000
# Name: 0, dtype: object

# %%
df2
# Out:
#        Name  Age       City   Salary
# 0  Rajneesh   18      India   900000
# 1     Rohit   25    NewYork   100000
# 2      Alex   30    America  2000000
# 3      Anuj   35  Austriala   400000

# %%
df2.loc[:1,"City":"Salary"]
# Out:
#       City  Salary
# 0    India  900000
# 1  NewYork  100000

# %%
df2.loc[[0,1]][["City","Salary"]]
# Out:
#       City  Salary
# 0    India  900000
# 1  NewYork  100000

# %%
df2
# Out:
#        Name  Age       City   Salary
# 0  Rajneesh   18      India   900000
# 1     Rohit   25    NewYork   100000
# 2      Alex   30    America  2000000
# 3      Anuj   35  Austriala   400000

# %%
df2.loc[[2,3]][["Name","Age"]]
# Out:
#    Name  Age
# 2  Alex   30
# 3  Anuj   35

# %% [markdown]
# ##Conditional Selection

# %%
df2[df2["Age"] < 30]
# Out:
#        Name  Age     City  Salary
# 0  Rajneesh   18    India  900000
# 1     Rohit   25  NewYork  100000

# %%
df2[(df2["Age"] < 30) & (df2["City"]=="India")]
# Out:
#        Name  Age   City  Salary
# 0  Rajneesh   18  India  900000

# %% [markdown]
# ##Missing Data

# %% [markdown]
# ####Finding missing data

# %%
data = {

        "A":[1,2,3,4,5],
        "B":[np.nan,np.nan,3,4,5],
        "C":[1,2,3,np.nan,np.nan],
        "D":[1,2,np.nan,np.nan,3],
       }

# %%
df = pd.DataFrame(data)

# %%
df.isna().sum()
# Out:
# A    0
# B    2
# C    2
# D    2
# dtype: int64

# %%
df.isna().any()
# Out:
# A    False
# B     True
# C     True
# D     True
# dtype: bool

# %% [markdown]
# ###Removing Missing Data

# %%
# removing missing data work on rows cases
df.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df
# Out:
#    A    B    C    D
# 0  1  NaN  1.0  1.0
# 1  2  NaN  2.0  2.0
# 2  3  3.0  3.0  NaN
# 3  4  4.0  NaN  NaN
# 4  5  5.0  NaN  3.0

# %% [markdown]
# ## Filling the Missing Data

# %%
df.fillna(0)  # inplace = True for the real change,
# Out:
#    A    B    C    D
# 0  1  0.0  1.0  1.0
# 1  2  0.0  2.0  2.0
# 2  3  3.0  3.0  0.0
# 3  4  4.0  0.0  0.0
# 4  5  5.0  0.0  3.0

# %%
df
# Out:
#    A    B    C    D
# 0  1  NaN  1.0  1.0
# 1  2  NaN  2.0  2.0
# 2  3  3.0  3.0  NaN
# 3  4  4.0  NaN  NaN
# 4  5  5.0  NaN  3.0

# %%
values = {"A":0,"B":1,"C":2,"D":3}
df.fillna(value=values)
# Out:
#    A    B    C    D
# 0  1  1.0  1.0  1.0
# 1  2  1.0  2.0  2.0
# 2  3  3.0  3.0  3.0
# 3  4  4.0  2.0  3.0
# 4  5  5.0  2.0  3.0

# %%
df.fillna(df.mean())
# Out:
#    A    B    C    D
# 0  1  4.0  1.0  1.0
# 1  2  4.0  2.0  2.0
# 2  3  3.0  3.0  2.0
# 3  4  4.0  2.0  2.0
# 4  5  5.0  2.0  3.0

# %% [markdown]
# ##Merging Joining and Concatenation

# %% [markdown]
# ####Merge 2 DataFrames

# %%
employees = pd.DataFrame({
    'employee_id': [1, 2, 3, 4, 5],
    'name': ['John', 'Anna', 'Peter', 'Linda', 'Bob'],
    'department': ['HR', 'IT', 'Finance', 'IT', 'HR']
})

# DataFrame 2: Salary information
salaries = pd.DataFrame({
    'employee_id': [1, 2, 3, 6, 7],
    'salary': [60000, 80000, 65000, 70000, 90000],
    'bonus': [5000, 10000, 7000, 8000, 12000]
})

# %%
pd.merge(employees,salaries,on="employee_id",how="inner")
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000

# %%
pd.merge(employees,salaries,on="employee_id",how="outer") # outer means on column basis
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN
# 5            6    NaN        NaN  70000.0   8000.0
# 6            7    NaN        NaN  90000.0  12000.0

# %%
pd.merge(employees,salaries,on="employee_id",how="left") # outer means on column basis
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN

# %%
pd.merge(employees,salaries,on="employee_id",how="right") # outer means on column basis
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000
# 3            6    NaN        NaN   70000   8000
# 4            7    NaN        NaN   90000  12000

# %% [markdown]
# ##Concatenation of  2 Data Frames

# %%
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2'],
    'C': ['C0', 'C1', 'C2']
})

df2 = pd.DataFrame({
    'A': ['A3', 'A4', 'A5'],
    'B': ['B3', 'B4', 'B5'],
    'C': ['C3', 'C4', 'C5']
})

# %%
df1
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %%
df2
# Out:
#     A   B   C
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     A   B   C   A   B   C
# 0  A0  B0  C0  A3  B3  C3
# 1  A1  B1  C1  A4  B4  C4
# 2  A2  B2  C2  A5  B5  C5

# %% [markdown]
# ## Joining two data Frames

# %%
df1 = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie']
}, index=[1, 2, 3])

# Second DataFrame
df2 = pd.DataFrame({
    'score': [85, 90, 75]
}, index=[2, 3, 4])

# %%
df1.join(df2,how="outer")
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0
# 4      NaN   75.0

# %% [markdown]
# ## Group By

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)

# %%
cat  = df.groupby("Store")["Sales"].sum()

print("sum of all sales of stores: ",cat)
# for i,v in cat:
#   print(f"{i}")
#   print(f"{v}")
# Out:
# sum of all sales of stores:  Store
# S1    720
# S2    780
# Name: Sales, dtype: int64

# %% [markdown]
# ##Aggregation

# %%
df["Sales"].mean()
# Out:
# np.float64(187.5)

# %%
df["Sales"].agg(["mean","median","sum","min","max"])
# Out:
# mean       187.5
# median     190.0
# sum       1500.0
# min        100.0
# max        300.0
# Name: Sales, dtype: float64

# %% [markdown]
# ###Pivot Table

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    136     24   John  January      Q1
# 1  2023-01-02       B   West    522     86   Mary  January      Q1
# 2  2023-01-03       C  North    537     37    Bob  January      Q1
# 3  2023-01-04       D  South    648     35  Alice  January      Q1
# 4  2023-01-05       A   East    375     78   John  January      Q1
# 5  2023-01-06       B   West    448     39   Mary  January      Q1
# 6  2023-01-07       C  North    270     34    Bob  January      Q1
# 7  2023-01-08       D  South    386     41  Alice  January      Q1
# 8  2023-01-09       A   East    485     67   John  January      Q1
# 9  2023-01-10       B   West    409     67   Mary  January      Q1
# 10 2023-01-11       C  North    316     13    Bob  January      Q1
# 11 2023-01-12       D  South    561     81  Alice  January      Q1
# 12 2023-01-13       A   East    690     83   John  January      Q1
# ...

# %%
pd.pivot_table(df,values="Sales",index="Region",columns="Product",aggfunc="median")
# Out:
# Product      A      B      C      D
# Region
# East     485.0    NaN    NaN    NaN
# North      NaN    NaN  395.0    NaN
# South      NaN    NaN    NaN  572.0
# West       NaN  522.0    NaN    NaN

# %% [markdown]
# # CrossTab

# %%
# cross tab give the counts
pd.crosstab(df["Region"],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %% [markdown]
# ##Operations

# %% [markdown]
# ##DataFrame basic Operations
# ###Which is called data preprocessing

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3, 4],
    'B': [10, 20, 30, 40],
    'C': [100, 200, 300, 400]
})
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400

# %%
df1.shape
# Out:
# (4, 3)

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int64
#  1   B       4 non-null      int64
#  2   C       4 non-null      int64
# dtypes: int64(3)
# memory usage: 228.0 bytes

# %%
df1.describe()
# Out:
#               A          B           C
# count  4.000000   4.000000    4.000000
# mean   2.500000  25.000000  250.000000
# std    1.290994  12.909944  129.099445
# min    1.000000  10.000000  100.000000
# 25%    1.750000  17.500000  175.000000
# 50%    2.500000  25.000000  250.000000
# 75%    3.250000  32.500000  325.000000
# max    4.000000  40.000000  400.000000

# %%
df1["A"]+10
# Out:
# 0    11
# 1    12
# 2    13
# 3    14
# Name: A, dtype: int64

# %%
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400

# %% [markdown]
# ##Data Frame applying functions

# %%
def square(x):
  return x**2

df1["B"] = df1["B"].apply(square)

# %%
df1
# Out:
#    A     B    C
# 0  1   100  100
# 1  2   400  200
# 2  3   900  300
# 3  4  1600  400

# %%
df1["E"] = df1["B"].apply(square)

# %%
df1
# Out:
#    A     B    C        E
# 0  1   100  100    10000
# 1  2   400  200   160000
# 2  3   900  300   810000
# 3  4  1600  400  2560000
